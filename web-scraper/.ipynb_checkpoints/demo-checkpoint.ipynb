# %%
import requests

# %%
req = requests.get('https://api.jcdecaux.com/vls/v1/stations?apiKey=92be62130be380ad2925b05fc3b1e5b3ef1a5a55')

# %%
req
# Out:
# <Response [200]>

# %%
req.json()
# Out:
# [{'number': 9087,
#   'contract_name': 'Marseille',
#   'name': '9087-MAZARGUES',
#   'address': 'MAZARGUES - ROND POINT DE MAZARGUES (OBELISQUE)',
#   'position': {'lat': 43.250903869637334, 'lng': 5.403244616491982},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 21,
#   'available_bike_stands': 12,
#   'available_bikes': 9,
#   'status': 'OPEN',
#   'last_update': 1550571440000},
#  {'number': 280,
#   'contract_name': 'Bruxelles-Capitale',
#   'name': '280 - HEYSEL / HEISEL',
#   'address': "HEYSEL / HEISEL - AVENUE DE L'IMPERATRICE CHARLOTTE / KEIZERIN CHARLOTTELAAN",
#   'position': {'lat': 50.897522, 'lng': 4.334831},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 13,
#   'available_bikes': 12,
#   'status': 'OPEN',
#   'last_update': 1550571841000},
#  {'number': 122,
#   'contract_name': 'Brisbane',
#   'name': '122 - LOWER RIVER TCE / ELLIS ST',
#   'address': 'Lower River Tce / Ellis St',
# ...
